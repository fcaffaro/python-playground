# %%
# !pip install playwright
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !python -m playwright install chromium

# %%
# !python -m playwright codegen https://example.com

# %% [markdown]
# fter recording the automation routine, some scratch code is generated. Then we need to make sure that it works correctly and fix it in case of any issues.
#
# The `page.wait_for_load_state("networkidle")` can be a useful addition to ensure that the page is fully loaded before interacting with it.
